# %% [markdown]
# #Exploratory Functions

# %%
# Data Frame Exploration 

def explore_df(Data_Frame):
  ### This function finds exploratory information on the DataFrame, and Returns a Summary ###
    # Explore
  Data_Frame_head = Data_Frame.head()
  Data_Frame_shape = Data_Frame.shape
  Data_Frame_nulls = Data_Frame.isnull().sum()
  Data_Frame_null_sum = Data_Frame.isnull().sum().sum()
  Data_Frame_desc = Data_Frame.describe()
  Data_Frame_info = Data_Frame.info()
    #Summary
  print(f'''

  
Text Data Frame Exploration Values

Shape: {Data_Frame_shape}

Total Null Values: {Data_Frame_null_sum}
Null Distribution:
{Data_Frame_nulls}

Data Statistical Summary:
{Data_Frame_desc}
''')
  return Data_Frame_head

# %%
# Column Exploration

def col_info(col):
  ### This function returns column information ###
  col_total = col.value_counts().sum()
  col_Val_count = col.value_counts()
  col_freq = col.value_counts(normalize=True)*100
  col_unique = col.nunique()

  print(f"""
There are {col_total} samples in {col_unique} cateogries.
  
Sample Count per Category:
{col_Val_count}

Sample Frequency per Category:
{col_freq}
  """)

# %% [markdown]
# #Examining the available Data Sets
#
# [Data Set Source](https://mushroom.mathematik.uni-marburg.de/)
#
#
#
# 1.   Primary Data Set
# 2.   Secondary Data Set Generated
# 3.   Secondary Data Set No Missing Values

# %%
import pandas as pd

# %%
#Primary

  #Data Set
df1_url ='https://raw.githubusercontent.com/CelinaWalkowicz/Mushroom_Analysis/main/primary_data_generated.csv'
df1 = pd.read_csv(df1_url, delimiter=";")

explore_df(df1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   family                0 non-null      float64
#  1   name                  236 non-null    object
#  2   class                 236 non-null    object
#  3   cap-diameter          236 non-null    object
#  4   cap-shape             119 non-null    object
#  5   cap-surface           100 non-null    object
#  6   cap-color             122 non-null    object
#  7   does-bruise-or-bleed  236 non-null    object
#  8   gill-attachment       119 non-null    object
#  9   gill-spacing          75 non-null     object
#  10  gill-color            115 non-null    object
#  11  stem-height           236 non-null    object
#  12  stem-width            236 non-null    object
#  13  stem-root             9 non-null      object
#  14  stem-surface          63 non-null     object
# ...

# %%
# Secondary Gen

  #Data Set
df2_url = 'https://raw.githubusercontent.com/CelinaWalkowicz/Mushroom_Analysis/main/secondary_data_generated.csv'
df2 = pd.read_csv(df2_url, delimiter=";")

explore_df(df2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61069 entries, 0 to 61068
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class                 61069 non-null  object
#  1   cap-diameter          61069 non-null  float64
#  2   cap-shape             61069 non-null  object
#  3   cap-surface           46949 non-null  object
#  4   cap-color             61069 non-null  object
#  5   does-bruise-or-bleed  61069 non-null  object
#  6   gill-attachment       51185 non-null  object
#  7   gill-spacing          36006 non-null  object
#  8   gill-color            61069 non-null  object
#  9   stem-height           61069 non-null  float64
#  10  stem-width            61069 non-null  float64
#  11  stem-root             9531 non-null   object
#  12  stem-surface          22945 non-null  object
#  13  stem-color            61069 non-null  object
#  14  veil-type             3177 non-null   object
# ...

# %%
# Secondary Gen No Miss

  # Data Set
df3_url = 'https://raw.githubusercontent.com/CelinaWalkowicz/Mushroom_Analysis/main/secondary_data_no_miss.csv'
df3 = pd.read_csv(df3_url, delimiter=";")

explore_df(df3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61069 entries, 0 to 61068
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class                 61069 non-null  object
#  1   cap-diameter          61069 non-null  float64
#  2   cap-shape             61069 non-null  object
#  3   cap-surface           61069 non-null  object
#  4   cap-color             61069 non-null  object
#  5   does-bruise-or-bleed  61069 non-null  object
#  6   gill-attachment       61069 non-null  object
#  7   gill-spacing          61069 non-null  object
#  8   gill-color            61069 non-null  object
#  9   stem-height           61069 non-null  float64
#  10  stem-width            61069 non-null  float64
#  11  stem-color            61069 non-null  object
#  12  has-ring              61069 non-null  object
#  13  ring-type             61069 non-null  object
#  14  habitat               61069 non-null  object
# ...

# %% [markdown]
# #Exploring Cap Colors
#
# 1.   Primary Data Set
# 2.   Secondary Data Set

# %%
# 1. Primary Data Set Cap Color Information 

col_info(df1['cap-color'])
# Out:
# There are 122 samples in 45 cateogries.
#
# Sample Count per Category:
# [n]             32
# [y]              9
# [n, y]           8
# [n, e]           6
# [n, w]           6
# [w]              6
# [n, o]           3
# [o]              3
# [n, p]           3
# [l]              2
# [r, l, w]        2
# [w, y]           2
# [y, n]           2
# [n, p, e]        2
# [n, k]           2
# [y, o]           2
# [e]              2
# [n, o, n]        2
# [b]              2
# [n, r, y]        1
# [n, p, e, y]     1
# [y, n, e, y]     1
# [n, b]           1
# [k]              1
# [n, w, w]        1
# [n, n, y]        1
# [b, p, e, y]     1
# [r, p, y]        1
# [k, n]           1
# [n, e, o]        1
# [n, e, y]        1
# [n, n, y, o]     1
# [n, o, y]        1
# [r]              1
# [n, n]           1
# [n, e, y, o]     1
# [n, r, y, l]     1
# [p, e, o]        1
# [l, k]           1
# [n, r, u, y]     1
# [p, u]           1
# [p]              1
# [u, y]           1
# [p, w]           1
# ...

# %%
# 2. Secondary Data Set

col_info(df2['cap-color'])
# Out:
# There are 61069 samples in 12 cateogries.
#
# Sample Count per Category:
# n    24218
# y     8543
# w     7666
# g     4420
# e     4035
# o     3656
# r     1782
# u     1709
# p     1703
# k     1279
# b     1230
# l      828
# Name: cap-color, dtype: int64
#
# Sample Frequency per Category:
# n    39.656782
# y    13.989094
# w    12.553014
# g     7.237715
# e     6.607280
# o     5.986671
# r     2.918011
# u     2.798474
# p     2.788649
# k     2.094352
# b     2.014115
# l     1.355843
# Name: cap-color, dtype: float64
